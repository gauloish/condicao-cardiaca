# %% [markdown]
# # Análise Exploratória de Dados
#
# Nesse notebook iremos fazer a análise exploratória dos dados do nosso dataset, analisando estatísticas, correlações, gráficos e fazendo alguns testes estatísticos para conhecermos melhor os dados.

# %% [markdown]
# ## Importando as Bibliotecas
#
# Primeiramente vamos importar nossas bibliotecas.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %% [markdown]
# ## Carregando o Dataset
#
# Agora, vamos carregar nosso dataset que passou por um pre-processamento inicial.

# %%
df = pd.read_parquet("../data/processed/UCMF_processed.parquet")

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Informações Iniciais
#
# Vamos analisar algumas informações iniciais, como tamanho do dataset (quantidade de registros e features), tipos das features, valores faltantes e balanceamento das classes alvo.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12873 entries, 0 to 12872
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             12873 non-null  Int64
#  1   peso           9945 non-null   Float64
#  2   altura         8413 non-null   Int64
#  3   imc            8037 non-null   Int64
#  4   atendimento    11577 non-null  datetime64[us]
#  5   nascimento     11242 non-null  datetime64[us]
#  6   idade          11255 non-null  Float64
#  7   convenio       8765 non-null   category
#  8   pulsos         11679 non-null  category
#  9   pa_sistolica   5143 non-null   Int64
#  10  pa_diastolica  5133 non-null   Int64
#  11  ppa            11160 non-null  category
#  12  patologia      11705 non-null  category
#  13  b2             11695 non-null  category
#  14  sopro          11706 non-null  category
#  15  fc             11005 non-null  Int64
#  16  hda1           8603 non-null   category
# ...

# %% [markdown]
# Como podemos ver, temos $12873$ registros, $20$ features e um target, a variável `"patologia"`. Além disso nossas variáveis estão com seus tipos apropriados e todas, com exceção de `"id"`, possuem valores faltantes, incluíndo a variável alvo. Agora vamos olhar para o balanceamento das classes do target.

# %%
df["patologia"].value_counts(dropna=False)
# Out:
# patologia
# ausente     6745
# presente    4960
# NaN         1168
# Name: count, dtype: int64
