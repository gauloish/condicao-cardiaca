# %% [markdown]
# # Preparação dos Dados
#
# [...]

# %% [markdown]
# ## Importando as Bibliotecas
#
# Primeiramente vamos importar nossas bibliotecas.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %% [markdown]
# ## Carregando o Dataset
#
# Agora, vamos carregar nosso dataset que já passou pelo processo de limpeza.

# %%
df = pd.read_parquet("../data/processed/UCMF_cleaned.parquet")

# %% [markdown]
# # Tratando Valores Faltantes
#
# Vamos inicialmente tratar os valores faltantes do nosso dataset. Primeiro vamos detectar os valores faltantes do nosso dataset.

# %%
df_na_count = df.isna().sum()
total = df.shape[0]

df_missing = pd.DataFrame({
    "Contagem de NA": df_na_count,
    "Porcentagem": (100*df_na_count / total).round(2),
})

df_missing
# Out:
#                Contagem de NA  Porcentagem
# id                          0         0.00
# peso                     2928        22.75
# altura                   4460        34.65
# imc                      4836        37.57
# atendimento              1296        10.07
# nascimento               1631        12.67
# idade                    1618        12.57
# convenio                 4108        31.91
# pulsos                   1194         9.28
# pa_sistolica             7730        60.05
# pa_diastolica            7740        60.13
# ppa                      1713        13.31
# patologia                1168         9.07
# b2                       1178         9.15
# sopro                    1167         9.07
# fc                       1868        14.51
# hda1                     4270        33.17
# hda2                    12466        96.84
# sexo                        4         0.03
# motivo1                  1055         8.20
# motivo2                  3496        27.16

# %% [markdown]
# Como podemos ver, temos valores faltantes em todas as features, exceto em `"id"`. Além disso temos valores faltantes até mesmo no target, o que é uma situação um pouco incomum. Primeiramente vamos lidar com os valores faltantes no target removendo eles, já que eles não trazem informação nenhuma para nosso modelo supervisionado. Além disso vamos salvar esse dataset para uso posterior.

# %%
df = df.dropna(subset="patologia")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11705 entries, 0 to 12872
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             11705 non-null  int64
#  1   peso           9587 non-null   float64
#  2   altura         8078 non-null   float64
#  3   imc            7708 non-null   float64
#  4   atendimento    11174 non-null  datetime64[us]
#  5   nascimento     10855 non-null  datetime64[us]
#  6   idade          10865 non-null  float64
#  7   convenio       8379 non-null   category
#  8   pulsos         11657 non-null  category
#  9   pa_sistolica   5131 non-null   float64
#  10  pa_diastolica  5121 non-null   float64
#  11  ppa            10768 non-null  category
#  12  patologia      11705 non-null  category
#  13  b2             11674 non-null  category
#  14  sopro          11682 non-null  category
#  15  fc             10986 non-null  float64
#  16  hda1           8565 non-null   category
#  17  hda2           402 non-null    category
#  18  sexo           11701 non-null  category
#  19  motivo1        11426 non-null  category
#  20  motivo2        9015 non-null   category
# dtypes: category(11), datetime64[us](2), float64(7), int64(1)
# memory usage: 1.1 MB

# %%
df.to_parquet("../data/processed/prepared/UCMF_with_missing.parquet")

# %% [markdown]
# ### Investigando os Valores Faltantes
#
# Agora vamos investigar se esses valores faltantes são aleatórios ou não. Primeiro vamos criar algumas visualizações importantes dos nossos valores faltantes. Primeiro vamos olhar para o padrão nos valores faltantes.

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# Como podemos ver alguns pares de features apresentam um padrão parecido nos valores faltantes, sendo eles os seguintes pares: (`"altura"`, `"imc"`), (`"nascimento"`, `"idade"`) e (`"pa_sistolica"`, `"pa_diastolica"`). No primeiro caso faz sentido pois o $\text{IMC}$ é calculado a partir do peso e da altura, portanto se eu tenho dados faltantes em um dos dois então eu tenho dados faltantes no $\text{IMC}$. O mesmo argumento é usado no caso do nascimento e da idade. Por fim, o último caso ocorre porque ao medirmos a pressão sanguínea temos que medir tanto a sistólica quanto a diastólica, então se uma das duas não foi coletada então a outra também não foi. As demais features parecem ter valores faltantes aleatórios, portanto podemos analisar as correlações entre eles.

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# Com essa matriz de correlação podemos confirmar nossa observação anterior e adicionar mais alguns pares correlacionados, a saber: (`"peso"`, `"imc"`), (`"ppa"`, `"idade"`), (`"ppa"`, `"nascimento"`) e (`"b2"`, `"sopro"`). Agora só para confirmar essas observações, vamos olhar os agrupamentos dessas features baseados nos valores faltantes.

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# Com isso fica confirmado nossas observações. Agora vamos analisar a relação entre os dados faltantes e nosso target. Para isso primeiro iremos criar um dataframe missing indicator que basicamente é um dataframe idêntico ao original mas os valores são `True` ou `False` indicando que o valor subjacente está faltando ou não no dataframe original. Com esse dataframe iremos treinar um modelo de Random Forest com validação cruzada estratificada e checaremos o desempenho do modelo para determinarmos se os valores faltantes têm informação sobre o target ou não. Dessa forma poderemos saber como lidar com os valores faltantes.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import (
    StratifiedKFold,
    cross_val_score
)

df_missing = df.isna().astype(int)

X = df_missing.drop("patologia", axis="columns")
y = df["patologia"].map({"ausente": 1, "presente": 0}).astype(int)

random_state = 42

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=random_state
)

model = RandomForestClassifier(
    random_state=random_state
)

scores = cross_val_score(
    model,
    X,
    y,
    cv=cv,
    scoring="roc_auc"
)

print(f"ROC-AUC: {100*scores.mean()}%")
print(f"STD:     {scores.std()}")
# Out:
# ROC-AUC: 62.96766272507711%
# STD:     0.010915450384894691

# %% [markdown]
# Como podemos ver, o $\text{ROC-AUC}$ foi de $62\%$. Esse valor é baixo mas ainda assim indica que os valores faltantes podem estar carregando informação relevante sobre o target. Por isso vamos treinar um modelo de Regressão Logística para sabermos as odds de cada feature em relação ao target. Além disso vamos olhar para as porcentagens de missing para termos uma noção melhor dos nossos dados.

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    max_iter=1000,
    random_state=random_state
)

model.fit(X, y)

missing_info = pd.DataFrame({
    "odds": np.exp(model.coef_)[0],
    "perc": 100*X.mean(),
}).round(2).sort_values(by="odds")

missing_info
# Out:
#                odds   perc
# pulsos         0.54   0.41
# fc             0.65   6.14
# pa_diastolica  0.68  56.25
# imc            0.71  34.15
# nascimento     0.74   7.26
# b2             0.77   0.26
# convenio       0.81  28.42
# ppa            0.95   8.01
# pa_sistolica   0.97  56.16
# id             1.00   0.00
# motivo1        1.01   2.38
# hda2           1.05  96.57
# peso           1.06  18.09
# idade          1.08   7.18
# sexo           1.22   0.03
# altura         1.26  30.99
# atendimento    1.47   4.54
# hda1           1.77  26.83
# motivo2        2.38  22.98
# sopro          2.78   0.20

# %% [markdown]
# Agora com essas informações podemos agrupar as features da seguinte forma:
#
# - **Grupo A**: Forte Efeito Positivo
#   - sopro
#   - motivo2
#   - hda1
#   - atendimento
#   - altura
#   - sexo
# - **Grupo B**: Forte Efeito Negativo
#   - pulsos
#   - fc
#   - pa_diastolica
#   - imc
#   - nascimento
#   - b2
#   - convenio
# - **Grupo C**: Nenhum Efeito
#   - ppa
#   - pa_sistolica
#   - id
#   - motivo1
#   - hda2
#   - peso
#   - idade
#
# O grupo A corresponde às features em que a presença do missing aumenta bastante as chances da classe positiva. Já o grupo B diminui as chances da classe negativa. Por fim, o grupo C tem baixo efeito na classe positiva. Agora vamos ignorar o grupo C e olhar para as features que possuem mais que $20\%$ de missing.
#
# - **Grupo A**: Forte Efeito Positivo
#   - motivo2
#   - hda1
#   - altura
# - **Grupo B**: Forte Efeito Negativo
#   - pa_diastolica
#   - imc
#   - convenio
#
# Essas features têm forte efeito nas odds da classe positiva e possuem uma taxa razoável de missing, portanto criaremos indicadores de missing para essas variáveis.

# %%
cols = [
    "motivo2",
    "hda1",
    "altura",
    "pa_diastolica",
    "imc",
    "convenio"
]

for col in cols:
    df[f"{col}_faltante"] = df[col].isna().astype("boolean")

df.head()
# Out:
#    id  peso  altura   imc atendimento nascimento  idade convenio   pulsos  \
# 0   1   5.0    51.0  19.0  2006-05-11 2006-03-30   0.12       gs  normais
# 1   2   3.5    50.0  14.0  2005-05-25 2005-05-19   0.02       gs  normais
# 2   3   NaN     NaN   NaN  2001-06-12 2005-05-08    NaN     sula  normais
# 3   4   8.1    65.0  19.0  2009-10-15 2009-04-21   0.50      NaN  normais
# 4   7  40.0   151.0  18.0  2008-01-14 1995-08-14  12.89     same  normais
#
#    pa_sistolica  ...  hda2       sexo                  motivo1  \
# 0           NaN  ...   NaN  masculino  suspeita_de_cardiopatia
# 1           NaN  ...   NaN  masculino  suspeita_de_cardiopatia
# 2           NaN  ...   NaN  masculino                 check_up
# 3           NaN  ...   NaN  masculino     parecer_cardiologico
# 4           NaN  ...   NaN  masculino     parecer_cardiologico
#
#                            motivo2 motivo2_faltante  hda1_faltante  \
# 0  palpitacao/taquicardia/arritmia            False          False
# 1                         dispneia            False          False
# 2                              NaN             True          False
# 3                              NaN             True          False
# 4                              NaN             True          False
#
#   altura_faltante pa_diastolica_faltante imc_faltante convenio_faltante
# 0           False                   True        False             False
# 1           False                   True        False             False
# 2            True                   True         True             False
# 3           False                   True        False              True
# 4           False                   True        False             False
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11705 entries, 0 to 12872
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      11705 non-null  int64
#  1   peso                    9587 non-null   float64
#  2   altura                  8078 non-null   float64
#  3   imc                     7708 non-null   float64
#  4   atendimento             11174 non-null  datetime64[us]
#  5   nascimento              10855 non-null  datetime64[us]
#  6   idade                   10865 non-null  float64
#  7   convenio                8379 non-null   category
#  8   pulsos                  11657 non-null  category
#  9   pa_sistolica            5131 non-null   float64
#  10  pa_diastolica           5121 non-null   float64
#  11  ppa                     10768 non-null  category
#  12  patologia               11705 non-null  category
#  13  b2                      11674 non-null  category
#  14  sopro                   11682 non-null  category
#  15  fc                      10986 non-null  float64
#  16  hda1                    8565 non-null   category
#  17  hda2                    402 non-null    category
#  18  sexo                    11701 non-null  category
#  19  motivo1                 11426 non-null  category
#  20  motivo2                 9015 non-null   category
#  21  motivo2_faltante        11705 non-null  boolean
#  22  hda1_faltante           11705 non-null  boolean
#  23  altura_faltante         11705 non-null  boolean
#  24  pa_diastolica_faltante  11705 non-null  boolean
#  25  imc_faltante            11705 non-null  boolean
#  26  convenio_faltante       11705 non-null  boolean
# dtypes: boolean(6), category(11), datetime64[us](2), float64(7), int64(1)
# memory usage: 1.3 MB

# %% [markdown]
# Agora, precisamos fazer algumas considerações importantes sobre esse dataset. O primeiro é que os valores faltantes nesse dataset podem ter algumas causas específicas, por exemplo, variáveis como `"pulsos"` e `"pa_sistolica"` podem estar faltando porque não foram medidas e não porque o valor não existe, até porque em ambos o valor existe. Já no caso do `"hda2"` o valor faltante pode simplesmente indicar que o paciente não teve um segundo histórico de doença (um argumento parecido pode ser usado para o `"motivo2"`). Além disso no caso do `"hda2"`, se não houver o primeiro histórico (`"hda1"`) não faz sentido ter um segundo histórico e isso é confirmado no código a seguir.

# %%
mask_1 = (X["hda1"] == True)
mask_2 = (X["hda2"] == False)

X[mask_1 & mask_2]
# Out:
#      id  peso  altura  imc  atendimento  nascimento  idade  convenio  pulsos  \
# 147   0     0       0    0            0           0      0         0       0
#
#      pa_sistolica  pa_diastolica  ppa  b2  sopro  fc  hda1  hda2  sexo  \
# 147             1              1    0   0      0   0     1     0     0
#
#      motivo1  motivo2
# 147        0        0

# %% [markdown]
# Como podemos ver, apenas um único registro possui um segundo histórico sem ter um primeiro. Isso indica que ambas as features possuem essa regra de negócio e portanto pode ser perigoso imputar valores em `"hda2"` pois isso pode acabar matando a informação de que o segundo histórico não foi preenchido porque não existia. E como citado anteriormente, isso também pode ocorrer com a feature `"motivo2"`. Dessa forma, podemos olhar para essas duas features `"hda2"` e `"motivo2"` com carinho e considerar que seus valores faltantes ocorre mais pela inexistência do valor em si e do que pelo fato dele não ter sido registrado. Portanto para ambos os casos iremos criar uma nova categoria que represente essa ausência e preencher todos os valores faltantes por essa categoria.

# %%
cols = ["motivo2", "hda2"]
na_cat = "nao_aplicavel"

for col in cols:
    df[col] = df[col].cat.add_categories(na_cat)
    df[col] = df[col].fillna(na_cat)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11705 entries, 0 to 12872
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      11705 non-null  int64
#  1   peso                    9587 non-null   float64
#  2   altura                  8078 non-null   float64
#  3   imc                     7708 non-null   float64
#  4   atendimento             11174 non-null  datetime64[us]
#  5   nascimento              10855 non-null  datetime64[us]
#  6   idade                   10865 non-null  float64
#  7   convenio                8379 non-null   category
#  8   pulsos                  11657 non-null  category
#  9   pa_sistolica            5131 non-null   float64
#  10  pa_diastolica           5121 non-null   float64
#  11  ppa                     10768 non-null  category
#  12  patologia               11705 non-null  category
#  13  b2                      11674 non-null  category
#  14  sopro                   11682 non-null  category
#  15  fc                      10986 non-null  float64
#  16  hda1                    8565 non-null   category
#  17  hda2                    11705 non-null  category
#  18  sexo                    11701 non-null  category
#  19  motivo1                 11426 non-null  category
#  20  motivo2                 11705 non-null  category
#  21  motivo2_faltante        11705 non-null  boolean
#  22  hda1_faltante           11705 non-null  boolean
#  23  altura_faltante         11705 non-null  boolean
#  24  pa_diastolica_faltante  11705 non-null  boolean
#  25  imc_faltante            11705 non-null  boolean
#  26  convenio_faltante       11705 non-null  boolean
# dtypes: boolean(6), category(11), datetime64[us](2), float64(7), int64(1)
# memory usage: 1.3 MB

# %% [markdown]
# ### Imputando nos Valores Faltantes
#
# Agora que criamos nossos indicadores de valores faltantes e tratamos algumas variáveis precisamos imputar valores nos valores faltantes. Aqui adotaremos três abordagens: `SimpleImputer`, `KNNImputer` e `IterativeImputer`. Para o `SimpleImputer`, iremos imputar a mediana nas features numéricas e a moda nas features não numéricas.

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

X = df.drop(["patologia", "atendimento", "nascimento"], axis="columns")
y = df.filter(["patologia"], axis="columns")

numeric_columns = X.select_dtypes(include="number").columns.to_list()
categorical_columns = X.select_dtypes(include="category").columns.to_list()

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
])

imputer = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_columns),
        ("cat", categorical_transformer, categorical_columns)
    ],
    remainder="passthrough"
)

X_t = imputer.fit_transform(X)

df_imputed = pd.DataFrame(
    X_t,
    columns=X.columns
)
df_imputed["patologia"] = y

df_imputed.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11705 entries, 0 to 11704
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      11705 non-null  object
#  1   peso                    11705 non-null  object
#  2   altura                  11705 non-null  object
#  3   imc                     11705 non-null  object
#  4   idade                   11705 non-null  object
#  5   convenio                11705 non-null  object
#  6   pulsos                  11705 non-null  object
#  7   pa_sistolica            11705 non-null  object
#  8   pa_diastolica           11705 non-null  str
#  9   ppa                     11705 non-null  str
#  10  b2                      11705 non-null  str
#  11  sopro                   11705 non-null  str
#  12  fc                      11705 non-null  str
#  13  hda1                    11705 non-null  str
#  14  hda2                    11705 non-null  str
#  15  sexo                    11705 non-null  str
#  16  motivo1                 11705 non-null  str
#  17  motivo2                 11705 non-null  str
#  18  motivo2_faltante        11705 non-null  object
#  19  hda1_faltante           11705 non-null  object
#  20  altura_faltante         11705 non-null  object
#  21  pa_diastolica_faltante  11705 non-null  object
#  22  imc_faltante            11705 non-null  object
#  23  convenio_faltante       11705 non-null  object
#  24  patologia               10608 non-null  category
# dtypes: category(1), object(14), str(10)
# memory usage: 3.3+ MB

# %%
df_imputed.to_parquet("../data/processed/prepared/UCMF_simple_imputer.parquet")

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OrdinalEncoder

numeric_transformer = Pipeline(steps=[
    ("imputer", KNNImputer()),
])

categorical_transformer = Pipeline(steps=[
    ("encoder", OrdinalEncoder()),
    ("imputer", KNNImputer()),
])

imputer = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_columns),
        ("cat", categorical_transformer, categorical_columns)
    ],
    remainder="passthrough"
)

X_t = imputer.fit_transform(X)

df_imputed = pd.DataFrame(
    X_t,
    columns=X.columns
)
df_imputed["patologia"] = y

df_imputed.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11705 entries, 0 to 11704
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      11705 non-null  object
#  1   peso                    11705 non-null  object
#  2   altura                  11705 non-null  object
#  3   imc                     11705 non-null  object
#  4   idade                   11705 non-null  object
#  5   convenio                11705 non-null  object
#  6   pulsos                  11705 non-null  object
#  7   pa_sistolica            11705 non-null  object
#  8   pa_diastolica           11705 non-null  object
#  9   ppa                     11705 non-null  object
#  10  b2                      11705 non-null  object
#  11  sopro                   11705 non-null  object
#  12  fc                      11705 non-null  object
#  13  hda1                    11705 non-null  object
#  14  hda2                    11705 non-null  object
#  15  sexo                    11705 non-null  object
#  16  motivo1                 11705 non-null  object
#  17  motivo2                 11705 non-null  object
#  18  motivo2_faltante        11705 non-null  object
#  19  hda1_faltante           11705 non-null  object
#  20  altura_faltante         11705 non-null  object
#  21  pa_diastolica_faltante  11705 non-null  object
#  22  imc_faltante            11705 non-null  object
#  23  convenio_faltante       11705 non-null  object
#  24  patologia               10608 non-null  category
# dtypes: category(1), object(24)
# memory usage: 2.2+ MB

# %%
df_imputed
# Out:
#             id   peso altura   imc  idade convenio pulsos pa_sistolica  \
# 0          1.0    5.0   51.0  19.0   0.12     95.0   57.0        112.0
# 1          2.0    3.5   50.0  14.0   0.02     95.0   57.0        128.0
# 2          3.0  23.32  110.6  18.0   5.73    100.0   62.0         88.0
# 3          4.0    8.1   65.0  19.0    0.5     97.0   57.0         92.0
# 4          7.0   40.0  151.0  18.0  12.89    110.0   67.0         96.0
# ...        ...    ...    ...   ...    ...      ...    ...          ...
# 11700  17869.0    9.5   76.0  16.0    1.2     96.0   56.0         92.0
# 11701  17870.0   12.0   75.0  21.0   0.81     96.0   56.0         90.0
# 11702  17871.0   65.0  175.0  21.0  24.34    126.0   80.0         76.0
# 11703  17872.0   27.0  134.0  15.0  8.436     90.0   50.0         81.2
# 11704  17873.0   44.5  144.0  19.0  11.38    110.0   80.0         80.0
#
#       pa_diastolica  ppa  ... sexo motivo1 motivo2 motivo2_faltante  \
# 0              89.0  3.0  ...  2.0     4.0    14.0            False
# 1              89.0  3.0  ...  2.0     4.0     9.0            False
# 2             216.0  3.0  ...  2.0     1.0    12.0             True
# 3             127.2  3.0  ...  2.0     3.0    12.0             True
# 4             177.0  3.0  ...  2.0     3.0    12.0             True
# ...             ...  ...  ...  ...     ...     ...              ...
# 11700         108.4  3.0  ...  2.0     3.0     8.0            False
# 11701         251.0  3.0  ...  2.0     3.0     8.0            False
# 11702         100.0  3.0  ...  0.0     0.0     4.0            False
# 11703          89.0  3.0  ...  0.0     4.0    10.0            False
# 11704          89.0  3.0  ...  0.0     4.0    10.0            False
#
#       hda1_faltante altura_faltante pa_diastolica_faltante imc_faltante  \
# 0             False           False                   True        False
# 1             False           False                   True        False
# 2             False            True                   True         True
# 3             False           False                   True        False
# 4             False           False                   True        False
# ...             ...             ...                    ...          ...
# 11700         False           False                   True        False
# 11701         False           False                   True        False
# 11702         False           False                  False        False
# 11703          True           False                  False        False
# 11704         False            True                  False         True
#
#       convenio_faltante patologia
# 0                 False  presente
# 1                 False  presente
# 2                 False  presente
# 3                  True  presente
# 4                 False  presente
# ...                 ...       ...
# 11700              True   ausente
# 11701             False  presente
# 11702             False   ausente
# 11703             False  presente
# 11704             False  presente
#
# [11705 rows x 25 columns]
